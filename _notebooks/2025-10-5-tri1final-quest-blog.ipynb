# %% [markdown]
# ---
# title: Quest of Code Blog
# comments: true
# layout: post
# menu: nav/csafinal.html
# permalink: /tri1final/quest
# description: Quest of Code Blog - Trimester 1 Final Review
# author: Manas
# ---

# %% [markdown]
# # Quest of Code Blog
#
# ## Profile/LinkedIn Quest - Sprint 3
#
# This sprint focused on professional development and creating an online presence.
#
# <img width="1023" height="791" alt="Image" src="https://github.com/user-attachments/assets/0a39ab89-8143-4bba-8e6f-a2378575870d" />
#
# ## Professional Profile Creation
#
# **GitHub Profile Enhancement:**
# - Added profile README
# - Organized repositories
# - Created professional bio
# - Added skills and technologies
#
# **LinkedIn Profile:**
# - Created professional account
# - Added education and experience
# - Listed technical skills
# - Connected with classmates and teachers
#
# **Portfolio Website:**
# - Expanded GitHub Pages site
# - Added project showcases
# - Created about me section
# - Documented learning journey
#
# ## Projects Showcased
#
# **1. Phone Class Project**
# - Demonstrated OOP understanding
# - Showed Java proficiency
# - Highlighted problem-solving skills
#
# **2. GitHub Pages Jokes Site**
# - Interactive web development
# - JavaScript DOM manipulation
# - Responsive design
#
# **3. Homework Portfolio**
# - Organized notebook collection
# - Documented learning progress
# - Showed consistent effort
#
# ## Professional Branding
#
# **Skills Highlighted:**
# - Java Programming
# - JavaScript & Python
# - Web Development (HTML/CSS)
# - Git & Version Control
# - GitHub Pages
#
# **Achievements:**
# - Completed all sprint assignments
# - Maintained consistent commit history
# - Created professional portfolio
# - Participated in collaborative projects
#
# ## Networking
#
# **Connections Made:**
# - Classmates in CSA course
# - Teachers and mentors
# - Developers in the community
# - Alumni from the program
#
# **Benefits:**
# - Learning opportunities
# - Career insights
# - Collaboration possibilities
# - Industry connections
#
# ---
#
# **Class of 2027 at DNHS**
