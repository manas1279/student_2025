# %% [raw]
# ---
# title: Trimester 1 Final Review
# comments: true
# layout: post
# permalink: /tri1final
# description: Trimester 1 Final Review
# author: Manas
# ---

# %% [markdown]
# # CSA Trimester 1 Final Review
#
#
#
# ## Navigation Menu
#
#
#
# | [Tools & My Journey]({{site.baseurl}}/tri1final/tools-journey) | [Tools Sprint Project]({{site.baseurl}}/tri1final/tools-jokes) | [Study Blog (Fundamentals)]({{site.baseurl}}/tri1final/study-blog) | [MCQ Review & Approach]({{site.baseurl}}/tri1final/mcq-review) | [Quest of Code Blog]({{site.baseurl}}/tri1final/quest-blog) | [N@tM Reflection]({{site.baseurl}}/tri1final/natm-reflection) | [Final Reflection]({{site.baseurl}}/tri1final/final-reflection) |
#
# |------------------------------------------|---------------------------------------------|------------------------------------------------------|-----------------------------------------------|-------------------------------------------|---------------------------------------------------------|---------------------------------------------------------------------------|
#
#
#
# ---
#
#
#
# ## Overview
#
#
#
# This is the main hub for my Trimester 1 Final Review. Click on any section in the navigation menu above to explore that topic in detail.
#
#
#
# Each section contains:
#
# - Detailed reflections and learnings
#
# - Code examples and project showcases
#
# - Analysis of growth and achievements
#
# - Goals for future learning
#
#
#
# ---
#
#
#
# **Class of 2026 at DNHS**
