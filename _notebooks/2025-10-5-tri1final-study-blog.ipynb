# %% [raw]
# ---
# title: Study Blog (Fundamentals)
# comments: true
# layout: post
# permalink: /tri1final/study-blog
# description: Study Blog (Fundamentals) - Trimester 1 Final Review
# author: Manas
# ---

# %% [markdown]
# # Study Blog (Fundamentals)## Navigation Menu| [Tools & My Journey]({{site.baseurl}}/tri1final/tools-journey) | [Tools Sprint Project]({{site.baseurl}}/tri1final/tools-jokes) | [Study Blog (Fundamentals)]({{site.baseurl}}/tri1final/study-blog) | [MCQ Review & Approach]({{site.baseurl}}/tri1final/mcq-review) | [Quest of Code Blog]({{site.baseurl}}/tri1final/quest-blog) | [N@tM Reflection]({{site.baseurl}}/tri1final/natm-reflection) | [Final Reflection]({{site.baseurl}}/tri1final/final-reflection) ||------------------------------------------|---------------------------------------------|------------------------------------------------------|-----------------------------------------------|-------------------------------------------|---------------------------------------------------------|---------------------------------------------------------------------------|---## Sprint 2: Fundamentals of JavaScript/PythonThis sprint focused on building foundational programming skills in both JavaScript and Python.## JavaScript Fundamentals**Variables and Data Types:**- `let`, `const`, and `var` declarations- Primitive types: String, Number, Boolean, Undefined, Null- Reference types: Objects, Arrays- Type coercion and conversion**Key Concepts:**```javascript// Variable declarationslet name = "Manas";const age = 16;var score = 100;// Data typeslet isStudent = true;        // Booleanlet courses = ["CSA", "CSP"]; // Arraylet student = {               // Object    name: "Manas",    grade: 11};```**DOM Manipulation:**- Selecting elements (`getElementById`, `querySelector`)- Event listeners and handlers- Dynamic content updates- Form handling and validation**Homework Completion:**- ✅ Variables and DOM homework- ✅ Event handling exercises- ✅ Interactive web page projects## Python Fundamentals**Variables and Data Types:**- Dynamic typing in Python- String, int, float, boolean types- Lists, dictionaries, tuples- Type conversion and casting**Key Concepts:**```python# Variablesname = "Manas"age = 16is_student = True# Data structurescourses = ["CSA", "CSP"]  # Liststudent = {                # Dictionary    "name": "Manas",    "grade": 11}```**Input/Output Operations:**- `print()` for output- `input()` for user input- File I/O basics- Data formatting**Homework Completion:**- ✅ Variables homework- ✅ Input/output exercises- ✅ Data type conversion projects## Comparison: JavaScript vs Python| Feature | JavaScript | Python ||---------|-----------|--------|| **Syntax** | Uses `let`, `const`, `var` | No declaration keywords || **Type System** | Dynamic, can be coerced | Dynamic, strict typing available || **Arrays** | `[1, 2, 3]` | `[1, 2, 3]` (same syntax) || **Objects** | `{key: value}` | `{"key": "value"}` (dictionaries) || **String Interpolation** | Template literals | f-strings |## Key Takeaways- Both languages share similar concepts but different syntax- Understanding one helps with the other- Practice is essential for mastery- Real-world applications differ between languages---**Class of 2026 at DNHS**
