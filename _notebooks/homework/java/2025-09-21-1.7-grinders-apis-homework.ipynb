// %% [markdown]
// ---
// title: Application Program Interface (API) and Libraries Homework
// description: Understanding Application Program Interfaces and Java Libraries - Homework
// layout: post
// type: hacks
// menu: nav/home.html
// toc: true
// permalink: /csa/unit_01/1_7/homework
// ---

// %% [markdown]
// ---
//
// ## 📝 Homework Hack: Phone Class
//
// Create a `Phone` class that demonstrates **all concepts** from this lesson:
// - Libraries/Classes
// - Packages (use ArrayList from java.util)
// - Attributes
// - Behaviors
//
// ### Requirements:
//
// **Attributes (4):**
// - `brand` (String)
// - `model` (String)
// - `batteryLevel` (int) - starts at 100
// - `contacts` (ArrayList<String>)
//
// **Behaviors (5 methods):**
// 1. Constructor - sets brand and model, initializes empty contacts list
// 2. `displayInfo()` - prints brand, model, and battery level
// 3. `addContact(String name)` - adds name to contacts list
// 4. `showContacts()` - prints all contacts
// 5. `usePhone(int minutes)` - decreases battery by minutes used
//
// **Testing:**
// - Create 2 Phone objects
// - Add 3 contacts to each phone
// - Use phone for some minutes
// - Display all information
//
// ### Grading:
// - Correct attributes (4 points)
// - Correct methods (5 points)
// - Proper use of ArrayList from java.util (3 points)
// - Complete testing (3 points)
// - **Total: 15 points**

// %% [markdown]
// <h1>My response</h1>

// %%
// Homework Hack: Completed

import java.util.ArrayList;

public class Phone {
    // 4 attributes
    private String brand;
    private String model;
    private int batteryLevel;
    private ArrayList<String> contacts;
    
    // Constructor - sets brand and model, initializes empty contacts list
    public Phone(String brand, String model) {
        this.brand = brand;
        this.model = model;
        this.batteryLevel = 100; // starts at 100
        this.contacts = new ArrayList<String>();
    }
    
    // displayInfo() method - prints brand, model, and battery level
    public void displayInfo() {
        System.out.println("Phone Info:");
        System.out.println("Brand: " + brand);
        System.out.println("Model: " + model);
        System.out.println("Battery Level: " + batteryLevel + "%");
        System.out.println();
    }
    
    // addContact(String name) method - adds name to contacts list
    public void addContact(String name) {
        contacts.add(name);
        System.out.println("Added contact: " + name);
    }
    
    // showContacts() method - prints all contacts
    public void showContacts() {
        System.out.println("Contacts for " + brand + " " + model + ":");
        if (contacts.isEmpty()) {
            System.out.println("No contacts found.");
        } else {
            for (int i = 0; i < contacts.size(); i++) {
                System.out.println((i + 1) + ". " + contacts.get(i));
            }
        }
        System.out.println();
    }
    
    // usePhone(int minutes) method - decreases battery by minutes used
    public void usePhone(int minutes) {
        batteryLevel -= minutes;
        if (batteryLevel < 0) {
            batteryLevel = 0;
        }
        System.out.println("Used phone for " + minutes + " minutes. Battery now at " + batteryLevel + "%");
    }
}

// Test your Phone class
public class PhoneTest {
    public static void main(String[] args) {
        // Create 2 Phone objects
        Phone phone1 = new Phone("Apple", "iPhone 15");
        Phone phone2 = new Phone("Samsung", "Galaxy S24");
        
        // Add 3 contacts to each phone
        System.out.println("=== Adding Contacts ===");
        phone1.addContact("John Doe");
        phone1.addContact("Jane Smith");
        phone1.addContact("Bob Johnson");
        
        phone2.addContact("Alice Brown");
        phone2.addContact("Charlie Wilson");
        phone2.addContact("Diana Lee");
        
        System.out.println();
        
        // Use phones for some minutes
        System.out.println("=== Using Phones ===");
        phone1.usePhone(15);
        phone1.usePhone(25);
        phone2.usePhone(30);
        phone2.usePhone(10);
        
        System.out.println();
        
        // Display all information
        System.out.println("=== Phone Information ===");
        phone1.displayInfo();
        phone1.showContacts();
        
        phone2.displayInfo();
        phone2.showContacts();
    }
}

PhoneTest.main(null);
// Out:
// === Adding Contacts ===
// Added contact: John Doe
// Added contact: Jane Smith
// Added contact: Bob Johnson
// Added contact: Alice Brown
// Added contact: Charlie Wilson
// Added contact: Diana Lee
//
// === Using Phones ===
// Used phone for 15 minutes. Battery now at 85%
// Used phone for 25 minutes. Battery now at 60%
// Used phone for 30 minutes. Battery now at 70%
// Used phone for 10 minutes. Battery now at 60%
//
// === Phone Information ===
// Phone Info:
// Brand: Apple
// Model: iPhone 15
// Battery Level: 60%
//
// Contacts for Apple iPhone 15:
// 1. John Doe
// 2. Jane Smith
// 3. Bob Johnson
//
// Phone Info:
// Brand: Samsung
// Model: Galaxy S24
// Battery Level: 60%
//
// Contacts for Samsung Galaxy S24:
// 1. Alice Brown
// 2. Charlie Wilson
// 3. Diana Lee
