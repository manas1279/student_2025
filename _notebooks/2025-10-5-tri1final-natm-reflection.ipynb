# %% [markdown]
# ---
# title: N@tM Reflection
# comments: true
# layout: post
# menu: nav/csafinal.html
# permalink: /tri1final/natm
# description: N@tM Reflection - Trimester 1 Final Review
# author: Manas
# ---

# %% [markdown]
# # N@tM Reflection
#
# ## Event Overview
#
# Night at the Museum was an incredible opportunity to showcase my work and see what my peers have accomplished throughout Trimester 1.
#
# ## Preparation
#
# **What I Prepared:**
# - GitHub Pages portfolio demonstration
# - Phone class code walkthrough
# - Sprint accomplishments summary
# - Learning journey timeline
# - Interactive demos of projects
#
# **Challenges Faced:**
# - Nervousness about presenting
# - Preparing concise explanations
# - Setting up demo environment
# - Time management for presentation
#
# ## Presentation Highlights
#
# **Portfolio Showcase:**
# - Walked through GitHub Pages site structure
# - Demonstrated navigation and organization
# - Showed code examples and projects
# - Explained learning progression
#
# **Code Demonstration:**
# - Live coding of Phone class
# - Explaining OOP concepts
# - Showing ArrayList usage
# - Demonstrating constructor and methods
#
# **Learning Journey:**
# - Began with basic tools knowledge
# - Progressed through sprints
# - Built confidence in coding
# - Developed professional portfolio
#
# ## Feedback Received
#
# **Positive Feedback:**
# - "Great organization of your GitHub Pages site!"
# - "Your Phone class implementation shows solid understanding of OOP"
# - "Impressive progress from beginning to now"
# - "Nice use of ArrayList and Java collections"
# - "Well-documented code with clear comments"
#
# **Constructive Suggestions:**
# - "Could add more comments explaining complex logic"
# - "Consider adding unit tests for your classes"
# - "Expand portfolio with more interactive demos"
# - "Continue building on these foundations"
#
# **Favorite Comments:**
# 1. **"Your code shows good understanding of ArrayList and Java collections"**
#    - This validated my learning and motivated me to continue
#
# 2. **"Great job on implementing all the requirements for the Phone class!"**
#    - Recognition of thorough work and attention to detail
#
# 3. **"Impressive progress from beginning to now"**
#    - Acknowledged the growth journey I've been on
#
# ## What I Learned from Others
#
# **Inspiration from Peers:**
# - Saw creative project implementations
# - Learned different coding styles
# - Discovered new tools and techniques
# - Gained ideas for future projects
#
# **Key Takeaways:**
# - Collaboration enhances learning
# - Different approaches solve same problems
# - Presentation skills are valuable
# - Sharing work helps improve it
#
# ## Impact on My Learning
#
# **Confidence Boost:**
# - Presenting work increased confidence
# - Positive feedback validated efforts
# - Seeing others' work inspired improvement
# - Realized progress made
#
# **Future Goals:**
# - Continue building on current projects
# - Explore more advanced topics
# - Collaborate more with peers
# - Present more at future events
#
# **Here are some pictures from the event**
#
# <img width="414" height="545" alt="Image 1" src="https://github.com/user-attachments/assets/9a89b959-7bd3-4577-a9c2-a8e082ee07ba" />
#
# <img width="414" height="545" alt="Image 2" src="https://github.com/user-attachments/assets/8af55b42-af0f-477c-9a1d-45b35bd15a3c" />
#
# ---
#
# **Class of 2027 at DNHS**
