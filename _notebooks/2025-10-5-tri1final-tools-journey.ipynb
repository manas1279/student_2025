# %% [raw]
# ---
# title: "Tools & My Journey"
# comments: true
# layout: post
# permalink: /tri1final/tools-journey
# description: "Tools & My Journey - Trimester 1 Final Review"
# author: Manas
# ---

# %% [markdown]
# # Tools & My Journey## Navigation Menu| [Tools & My Journey]({{site.baseurl}}/tri1final/tools-journey) | [Tools Sprint Project]({{site.baseurl}}/tri1final/tools-jokes) | [Study Blog (Fundamentals)]({{site.baseurl}}/tri1final/study-blog) | [MCQ Review & Approach]({{site.baseurl}}/tri1final/mcq-review) | [Quest of Code Blog]({{site.baseurl}}/tri1final/quest-blog) | [N@tM Reflection]({{site.baseurl}}/tri1final/natm-reflection) | [Final Reflection]({{site.baseurl}}/tri1final/final-reflection) ||------------------------------------------|---------------------------------------------|------------------------------------------------------|-----------------------------------------------|-------------------------------------------|---------------------------------------------------------|---------------------------------------------------------------------------|---## Development Environment SetupAt the beginning of Trimester 1, I started with minimal experience in development tools. Through Sprint 1, I've established a comprehensive development workflow.**Tools I've Mastered:**- **Git & GitHub**: Version control, branching, commits, pull requests- **VS Code**: Code editing, debugging, extensions, integrated terminal- **GitHub Pages**: Static site hosting, Jekyll themes, markdown rendering- **KASM**: Cloud-based development environments, remote coding- **Terminal/Command Line**: Navigation, file operations, Git commands### My Learning Journey**Week 1-2: Initial Setup**- Created GitHub account and repository- Set up VS Code with necessary extensions- Configured GitHub Pages site- Learned basic Git commands (clone, add, commit, push)**Week 3-4: Advanced Git**- Understanding branching and merging- Pull requests and code review process- Issue tracking and project management- Collaboration workflows**Week 5-6: Integration**- Connecting local development to GitHub Pages- Using KASM for cloud development- Setting up Jupyter notebooks- Markdown formatting and documentation### Key Achievements- ✅ Successfully deployed GitHub Pages site- ✅ Established consistent commit workflow- ✅ Created organized repository structure- ✅ Integrated multiple development tools seamlessly### Challenges Overcome- **Challenge**: Initial confusion with Git commands  - **Solution**: Practiced with small commits, used Git documentation- **Challenge**: GitHub Pages deployment issues  - **Solution**: Debugged Jekyll configuration, understood frontmatter- **Challenge**: KASM connection problems  - **Solution**: Worked with tech support, learned proper configuration---**Class of 2026 at DNHS**
