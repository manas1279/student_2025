# %% [raw]
# ---
# title: "Tools & My Journey"
# comments: true
# layout: post
# permalink: /tri1final/tools
# description: "Tools & My Journey - Trimester 1 Final Review"
# author: Manas
# ---

# %% [markdown]
# ---
#
# ## Development Environment Setup
#
# At the beginning of Trimester 1, I started with minimal experience in development tools. Through Sprint 1, I've established a comprehensive development workflow.
#
# **Tools I've Mastered:**
# - **Git & GitHub**: Version control, branching, commits, pull requests
# - **VS Code**: Code editing, debugging, extensions, integrated terminal
# - **GitHub Pages**: Static site hosting, Jekyll themes, markdown rendering
# - **KASM**: Cloud-based development environments, remote coding
# - **Terminal/Command Line**: Navigation, file operations, Git commands
#
# ### My Learning Journey
#
# **Week 1-2: Initial Setup**
# - Created GitHub account and repository
# - Set up VS Code with necessary extensions
# - Configured GitHub Pages site
# - Learned basic Git commands (clone, add, commit, push)
#
# **Week 3-4: Advanced Git**
# - Understanding branching and merging
# - Pull requests and code review process
# - Issue tracking and project management
# - Collaboration workflows
#
# **Week 5-6: Integration**
# - Connecting local development to GitHub Pages
# - Using KASM for cloud development
# - Setting up Jupyter notebooks
# - Markdown formatting and documentation
#
# ### Key Achievements
# - ✅ Successfully deployed GitHub Pages site
# - ✅ Established consistent commit workflow
# - ✅ Created organized repository structure
# - ✅ Integrated multiple development tools seamlessly
#
# ### Challenges Overcome
# - **Challenge**: Initial confusion with Git commands
#   - **Solution**: Practiced with small commits, used Git documentation
# - **Challenge**: GitHub Pages deployment issues
#   - **Solution**: Debugged Jekyll configuration, understood frontmatter
# - **Challenge**: KASM connection problems
#   - **Solution**: Worked with tech support, learned proper configuration
#
# ---
#
# **Class of 2027 at DNHS**
