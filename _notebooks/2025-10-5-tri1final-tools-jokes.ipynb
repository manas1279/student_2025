# %% [markdown]
# ---
# title: Tools Sprint Project
# comments: true
# layout: post
# menu: nav/csafinal.html
# permalink: /tri1final/tools
# description: Tools Sprint Project - Trimester 1 Final Review
# author: Manas
# ---

# %% [markdown]
# # Tools Sprint Project
#
# ---
#
#
#
# ## GitHub Pages Project
#
#
#
# One of the most fun projects this trimester was creating an interactive website using GitHub Pages. This project helped me apply all the tools I learned in Sprint 1.
#
#
#
# **Project Overview:**
#
# - Created interactive website
#
# - Used HTML, CSS, and JavaScript
#
# - Implemented dynamic content loading
#
# - Applied responsive design principles
#
#
#
# **Technical Implementation:**
#
# ```javascript
#
# // Example: Dynamic content loading
#
# function loadContent() {
#
#     const items = [
#
#         "Item 1",
#
#         "Item 2",
#
#         "Item 3"
#
#     ];
#
#     const randomItem = items[Math.floor(Math.random() * items.length)];
#
#     document.getElementById('content-display').innerHTML = randomItem;
#
# }
#
# ```
#
#
#
# **What I Learned:**
#
# - HTML structure and semantic elements
#
# - CSS styling and layout techniques
#
# - JavaScript DOM manipulation
#
# - Integration with GitHub Pages
#
# - Responsive web design basics
#
#
#
# **Skills Applied:**
#
# - Git version control for project management
#
# - VS Code for code editing
#
# - GitHub Pages for hosting
#
# - Markdown for documentation
#
#
#
# **Project Link**: [GitHub Pages Project Repository](https://github.com/yourusername/project)
#
#
#
# ---
#
#
#
# **Class of 2027 at DNHS**
